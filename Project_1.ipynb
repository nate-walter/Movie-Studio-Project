# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Looking at `imdb.title.principles`

# %%
imdb_title = pd.read_csv('Data/imdb.title.principals.csv.gz')
imdb_title.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdb_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
imdb_title.isna().sum()
# Out:
# tconst             0
# ordering           0
# nconst             0
# category           0
# job           850502
# characters    634826
# dtype: int64

# %%
imdb_title.columns
# Out:
# Index(['tconst', 'ordering', 'nconst', 'category', 'job', 'characters'], dtype='object')

# %%
print(imdb_title.nunique()) 
len(imdb_title)
# Out:
# tconst        143454
# ordering          10
# nconst        604546
# category          12
# job             2965
# characters    174762
# dtype: int64
# 1028186

# %%
imdb_title.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %% [markdown]
# ## Conclusions
#
#
# There is a lot of missing data from `job` as well as `characters`. Will check to see if other `.csv` from imdb have this information.

# %% [markdown]
# # Looking at the `imdb.title`

# %%
imdb_crew = pd.read_csv('Data/imdb.title.crew.csv.gz')
imdb_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdb_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
imdb_crew.isna().sum()
# Out:
# tconst           0
# directors     5727
# writers      35883
# dtype: int64

# %%
imdb_crew.columns
# Out:
# Index(['tconst', 'directors', 'writers'], dtype='object')

# %%
imdb_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %% [markdown]
# ## Conclusions
#
# `Writer` and `director` have missing values. Will see how to add values as I look at more data.

# %% [markdown]
# # Looking at `imdb.rating`

# %%
rating = pd.read_csv('Data/imdb.title.ratings.csv.gz')
rating.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
rating.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
rating.columns
# Out:
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
rating.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# ## Conclusions
#
# No data missing. No cleaning done.

# %% [markdown]
# # Merging the data

# %%
merged_data = imdb_title.merge(imdb_crew, on = 'tconst').merge(rating, on = 'tconst')
merged_data.head()
# Out:
#       tconst  ordering     nconst category  job                characters  \
# 0  tt0323808        10  nm0059247   editor  NaN                       NaN
# 1  tt0323808         1  nm3579312  actress  NaN          ["Beth Boothby"]
# 2  tt0323808         2  nm2694680    actor  NaN         ["Steve Thomson"]
# 3  tt0323808         3  nm0574615    actor  NaN  ["Sir Lachlan Morrison"]
# 4  tt0323808         4  nm0502652  actress  NaN   ["Lady Delia Morrison"]
#
#    directors    writers  averagerating  numvotes
# 0  nm0362736  nm0362736            3.9      2328
# 1  nm0362736  nm0362736            3.9      2328
# 2  nm0362736  nm0362736            3.9      2328
# 3  nm0362736  nm0362736            3.9      2328
# 4  nm0362736  nm0362736            3.9      2328

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629755 entries, 0 to 629754
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         629755 non-null  object
#  1   ordering       629755 non-null  int64
#  2   nconst         629755 non-null  object
#  3   category       629755 non-null  object
#  4   job            124945 non-null  object
#  5   characters     248129 non-null  object
#  6   directors      626240 non-null  object
#  7   writers        558935 non-null  object
#  8   averagerating  629755 non-null  float64
#  9   numvotes       629755 non-null  int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 52.9+ MB

# %%
merged_data.nunique()
# Out:
# tconst            73685
# ordering             10
# nconst           359919
# category             12
# job                2557
# characters       121452
# directors         51146
# writers           54414
# averagerating        91
# numvotes           7349
# dtype: int64

# %% [markdown]
# # Good Films
#
# Films that have an `averageraiting` > **8** and have at least **500** votes.

# %%
good_films = merged_data[(merged_data['averagerating'] > 8) & (merged_data['numvotes'] >= 500)]

# %%
good_films.sample(5)
# Out:
#            tconst  ordering     nconst         category       job  \
# 598771  tt7380226         9  nm0007124          actress       NaN
# 578943  tt6628102         3  nm0947986          actress       NaN
# 263294  tt2659414         5  nm1085908         director       NaN
# 196042  tt1201607         8  nm0057655         producer  producer
# 498544  tt6156350         4  nm2962374  archive_footage       NaN
#
#                               characters  directors  \
# 598771                      ["Minister"]  nm9276879
# 578943                 ["Asuman Karasu"]  nm0149196
# 263294                               NaN  nm1085908
# 196042                               NaN  nm0946734
# 498544  ["Himself - NYC Workers League"]  nm0193231
#
#                                         writers  averagerating  numvotes
# 598771                                nm9276879            8.8       694
# 578943            nm9831079,nm0946324,nm0149196            8.2     11928
# 263294  nm1085908,nm5587369,nm4494126,nm3858594            8.2     11282
# 196042                      nm0460141,nm0746830            8.1    691835
# 498544                                nm0193231            8.3      4014

# %%
good_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4373 entries, 635 to 628842
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         4373 non-null   object
#  1   ordering       4373 non-null   int64
#  2   nconst         4373 non-null   object
#  3   category       4373 non-null   object
#  4   job            1006 non-null   object
#  5   characters     1770 non-null   object
#  6   directors      4369 non-null   object
#  7   writers        3729 non-null   object
#  8   averagerating  4373 non-null   float64
#  9   numvotes       4373 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 375.8+ KB

# %%
good_films.isna().sum()
# Out:
# tconst              0
# ordering            0
# nconst              0
# category            0
# job              3367
# characters       2603
# directors           4
# writers           644
# averagerating       0
# numvotes            0
# dtype: int64

# %% [markdown]
# # Final Conclusions
#
# ## Still have to merge with the other data from Nate to put it all together.
#
# Only wanted to look at data that has a rating of **8** and above, while having at least **500** votes.
#
# There are still values missing for `job, character, directors, and writers`. Will determine if they should be dropped at a later time.

# %%
tn_cleaned = pd.read_csv('Data/tn_cleaned.csv')
tn_cleaned
# Out:
#       Unnamed: 0  id release_date  \
# 0              0   1  Dec 18 2009
# 1              1   2  May 20 2011
# 2              2   3   Jun 7 2019
# 3              3   4   May 1 2015
# 4              4   5  Dec 15 2017
# ...          ...  ..          ...
# 5777        5777  78  Dec 31 2018
# 5778        5778  79   Apr 2 1999
# 5779        5779  80  Jul 13 2005
# 5780        5780  81  Sep 29 2015
# 5781        5781  82   Aug 5 2005
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# 4               Star Wars Ep. VIII: The Last Jedi          317000000
# ...                                           ...                ...
# 5777                                       Red 11               7000
# 5778                                    Following               6000
# 5779                Return to the Land of Wonders               5000
# 5780                         A Plague So Pleasant               1400
# 5781                            My Date With Drew               1100
#
#       domestic_gross  worldwide_gross  release_month  release_day  \
# 0          760507625       2776345279             12           18
# 1          241063875       1045663875              5           20
# 2           42762350        149762350              6            7
# 3          459005868       1403013963              5            1
# 4          620181382       1316721747             12           15
# ...              ...              ...            ...          ...
# 5777               0                0             12           31
# 5778           48482           240495              4            2
# 5779            1338             1338              7           13
# 5780               0                0              9           29
# 5781          181041           181041              8            5
#
#       release_year
# 0             2009
# 1             2011
# 2             2019
# 3             2015
# 4             2017
# ...            ...
# 5777          2018
# 5778          1999
# 5779          2005
# 5780          2015
# 5781          2005
#
# [5782 rows x 10 columns]

# %%
tn_cleaned['movie'] = tn_cleaned['movie'].apply(lambda x: x.lower())
tn_cleaned
# Out:
#       Unnamed: 0  id release_date  \
# 0              0   1  Dec 18 2009
# 1              1   2  May 20 2011
# 2              2   3   Jun 7 2019
# 3              3   4   May 1 2015
# 4              4   5  Dec 15 2017
# ...          ...  ..          ...
# 5777        5777  78  Dec 31 2018
# 5778        5778  79   Apr 2 1999
# 5779        5779  80  Jul 13 2005
# 5780        5780  81  Sep 29 2015
# 5781        5781  82   Aug 5 2005
#
#                                             movie  production_budget  \
# 0                                          avatar          425000000
# 1     pirates of the caribbean: on stranger tides          410600000
# 2                                    dark phoenix          350000000
# 3                         avengers: age of ultron          330600000
# 4               star wars ep. viii: the last jedi          317000000
# ...                                           ...                ...
# 5777                                       red 11               7000
# 5778                                    following               6000
# 5779                return to the land of wonders               5000
# 5780                         a plague so pleasant               1400
# 5781                            my date with drew               1100
#
#       domestic_gross  worldwide_gross  release_month  release_day  \
# 0          760507625       2776345279             12           18
# 1          241063875       1045663875              5           20
# 2           42762350        149762350              6            7
# 3          459005868       1403013963              5            1
# 4          620181382       1316721747             12           15
# ...              ...              ...            ...          ...
# 5777               0                0             12           31
# 5778           48482           240495              4            2
# 5779            1338             1338              7           13
# 5780               0                0              9           29
# 5781          181041           181041              8            5
#
#       release_year
# 0             2009
# 1             2011
# 2             2019
# 3             2015
# 4             2017
# ...            ...
# 5777          2018
# 5778          1999
# 5779          2005
# 5780          2015
# 5781          2005
#
# [5782 rows x 10 columns]

# %%
tndb_cleaned = pd.read_csv('Data/tmdb_cleaned.csv')
tndb_cleaned
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               0      [12, 14, 10751]   12444                en
# 2               0      [12, 14, 10751]   12444                en
# 3               1  [14, 12, 16, 10751]   10191                en
# 4               1  [14, 12, 16, 10751]   10191                en
# ...           ...                  ...     ...               ...
# 47829       26515      [10751, 12, 28]  366854                en
# 47830       26515      [10751, 12, 28]  366854                en
# 47831       26515      [10751, 12, 28]  366854                en
# 47832       26516             [53, 27]  309885                en
# 47833       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 2      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 3                          How to Train Your Dragon      28.734   2010-03-26
# 4                          How to Train Your Dragon      28.734   2010-03-26
# ...                                             ...         ...          ...
# 47829                                  Trailer Made       0.600   2018-06-22
# 47830                                  Trailer Made       0.600   2018-06-22
# 47831                                  Trailer Made       0.600   2018-06-22
# 47832                                    The Church       0.600   2018-10-05
# 47833                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count  \
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 2      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 3                          How to Train Your Dragon           7.7        7610
# 4                          How to Train Your Dragon           7.7        7610
# ...                                             ...           ...         ...
# 47829                                  Trailer Made           0.0           1
# 47830                                  Trailer Made           0.0           1
# 47831                                  Trailer Made           0.0           1
# 47832                                    The Church           0.0           1
# 47833                                    The Church           0.0           1
#
#        genre_id
# 0          12.0
# 1          14.0
# 2       10751.0
# 3          14.0
# 4          12.0
# ...         ...
# 47829   10751.0
# 47830      12.0
# 47831      28.0
# 47832      53.0
# 47833      27.0
#
# [47834 rows x 11 columns]

# %%
tndb_cleaned['original_title'] = tndb_cleaned['original_title'].apply(lambda x: x.lower())
tndb_cleaned
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               0      [12, 14, 10751]   12444                en
# 2               0      [12, 14, 10751]   12444                en
# 3               1  [14, 12, 16, 10751]   10191                en
# 4               1  [14, 12, 16, 10751]   10191                en
# ...           ...                  ...     ...               ...
# 47829       26515      [10751, 12, 28]  366854                en
# 47830       26515      [10751, 12, 28]  366854                en
# 47831       26515      [10751, 12, 28]  366854                en
# 47832       26516             [53, 27]  309885                en
# 47833       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      harry potter and the deathly hallows: part 1      33.533   2010-11-19
# 1      harry potter and the deathly hallows: part 1      33.533   2010-11-19
# 2      harry potter and the deathly hallows: part 1      33.533   2010-11-19
# 3                          how to train your dragon      28.734   2010-03-26
# 4                          how to train your dragon      28.734   2010-03-26
# ...                                             ...         ...          ...
# 47829                                  trailer made       0.600   2018-06-22
# 47830                                  trailer made       0.600   2018-06-22
# 47831                                  trailer made       0.600   2018-06-22
# 47832                                    the church       0.600   2018-10-05
# 47833                                    the church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count  \
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 2      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 3                          How to Train Your Dragon           7.7        7610
# 4                          How to Train Your Dragon           7.7        7610
# ...                                             ...           ...         ...
# 47829                                  Trailer Made           0.0           1
# 47830                                  Trailer Made           0.0           1
# 47831                                  Trailer Made           0.0           1
# 47832                                    The Church           0.0           1
# 47833                                    The Church           0.0           1
#
#        genre_id
# 0          12.0
# 1          14.0
# 2       10751.0
# 3          14.0
# 4          12.0
# ...         ...
# 47829   10751.0
# 47830      12.0
# 47831      28.0
# 47832      53.0
# 47833      27.0
#
# [47834 rows x 11 columns]

# %%
cleaned_bom = pd.read_csv('Data/cleaned_bom.csv')
cleaned_bom
# Out:
#       Unnamed: 0                                        title      studio  \
# 0              0                                  Toy Story 3          BV
# 1              1                   Alice in Wonderland (2010)          BV
# 2              2  Harry Potter and the Deathly Hallows Part 1          WB
# 3              3                                    Inception          WB
# 4              4                          Shrek Forever After        P/DW
# ...          ...                                          ...         ...
# 3354        3382                                    The Quake       Magn.
# 3355        3383                  Edward II (2018 re-release)          FM
# 3356        3384                                     El Pacto        Sony
# 3357        3385                                     The Swan  Synergetic
# 3358        3386                            An Actor Prepares       Grav.
#
#       domestic_gross  year
# 0        415000000.0  2010
# 1        334200000.0  2010
# 2        296000000.0  2010
# 3        292600000.0  2010
# 4        238700000.0  2010
# ...              ...   ...
# 3354          6200.0  2018
# 3355          4800.0  2018
# 3356          2500.0  2018
# 3357          2400.0  2018
# 3358          1700.0  2018
#
# [3359 rows x 5 columns]

# %%
cleaned_bom['title'] = cleaned_bom['title'].apply(lambda x: x.lower())
cleaned_bom
# Out:
#       Unnamed: 0                                        title      studio  \
# 0              0                                  toy story 3          BV
# 1              1                   alice in wonderland (2010)          BV
# 2              2  harry potter and the deathly hallows part 1          WB
# 3              3                                    inception          WB
# 4              4                          shrek forever after        P/DW
# ...          ...                                          ...         ...
# 3354        3382                                    the quake       Magn.
# 3355        3383                  edward ii (2018 re-release)          FM
# 3356        3384                                     el pacto        Sony
# 3357        3385                                     the swan  Synergetic
# 3358        3386                            an actor prepares       Grav.
#
#       domestic_gross  year
# 0        415000000.0  2010
# 1        334200000.0  2010
# 2        296000000.0  2010
# 3        292600000.0  2010
# 4        238700000.0  2010
# ...              ...   ...
# 3354          6200.0  2018
# 3355          4800.0  2018
# 3356          2500.0  2018
# 3357          2400.0  2018
# 3358          1700.0  2018
#
# [3359 rows x 5 columns]
